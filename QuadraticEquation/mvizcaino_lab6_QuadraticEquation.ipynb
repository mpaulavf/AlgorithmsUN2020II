# %% [markdown]
# # Lab 6
#
# Maria Paula Vizcaíno Forero

# %% [markdown]
# # Implements the Classic and Po Shen Loh ‘s methods for solving quadratic equations
#
# We import the libraries beforehand

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import cmath

# %% [markdown]
# **1.**   Plot the following functions in a x range that include that include the vertex and the roots (if there are roots)

# %% [markdown]
# - $x^{2}$

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,x**2)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = $x^2$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# - $(x-1)^2$

# %%
# (x-1)^2 = x^2 - 2x + 1

x = np.linspace(-1.0,3.0,100)
fig, ax = plt.subplots()
ax.plot(x,x**2 - 2*x + 1)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = $(x-1)^{2}$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# - $x^2 -1$

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,x**2 - 1)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = $x^{2}-1$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# - $x^2 + 1$

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,x**2 + 1)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = $x^{2}+1$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# **2.** Apply the Classic and Po Shen Loh ‘s methods for solving the following quadratic equations

# %% [markdown]
# **Quadratic formula method**

# %%
def quadratic(a,b,c):
  roots = []
  num_sqrt= b**2 - (4*a*c)

  # First root
  if (num_sqrt>=0):
    numerator = -1*b + math.sqrt(num_sqrt)
    denominator = 2*a
    root1 = (numerator/denominator)
    roots.append(root1)
  else:
    numerator = -1*b + cmath.sqrt(num_sqrt)
    denominator = 2*a
    root1 = (numerator/denominator)
    roots.append(root1)
  
  # Second root
  if (num_sqrt>=0):
    numerator = -1*b - math.sqrt(num_sqrt)
    denominator = 2*a
    root2 = (numerator/denominator)
    roots.append(root2)
  else:
    numerator = -1*b - cmath.sqrt(num_sqrt)
    denominator = 2*a
    root2 = (numerator/denominator)
    roots.append(root2)
  
  # Result by quadratic
  if (roots[0] == roots[1]):
    roots.pop()
    return roots
  else:
    return roots

# %% [markdown]
# **Po Shen Loh's method**

# %%
def poshenloh(b,c):
  roots=[]
  if (b!=0):
    denominator = 4
  else:
    denominator = 1
  num_sqrt = b**2 - (c * denominator)

  numerator = -1 * b
  
  # First root
  if (num_sqrt>=0):
    root1 = (numerator/2)+math.sqrt(num_sqrt)
    roots.append(root1)
  else:
    root1 = (numerator/2)+cmath.sqrt(num_sqrt)
    roots.append(root1)

  # Second root
  if (num_sqrt>=0):
    root2 = (numerator/2)-math.sqrt(num_sqrt)
    roots.append(root2)
  else:
    root2 = (numerator/2)-cmath.sqrt(num_sqrt)
    roots.append(root2)

  # Result by Po Shen Loh
  if (roots[0] == roots[1]):
    roots.pop()
    return roots
  else:
    return roots

# %% [markdown]
# - $x^{2} = 0$

# %%
rq = quadratic(1,0,0)
print('Roots by quadratic method:', rq[0])
rp = poshenloh(0,0)
print('Roots by Po Shen Loh method:', rp[0])
# Out:
# Roots by quadratic method: 0.0
# Roots by Po Shen Loh method: 0.0

# %% [markdown]
# - $(x - 1)^{2} = 0$

# %%
# (x-1)^2 = x^2 - 2x + 1

rq = quadratic(1,-2,1)
print('Roots by quadratic method:', rq[0])
rp = poshenloh(-2,1)
print('Roots by Po Shen Loh method:', rp[0])
# Out:
# Roots by quadratic method: 1.0
# Roots by Po Shen Loh method: 1.0

# %% [markdown]
# - $x^{2} − 1 = 0$

# %%
rq = quadratic(1,0,-1)
print('Roots by quadratic method:', rq[0], ',', rq[1])
rp = poshenloh(0,-1)
print('Roots by Po Shen Loh method:', rp[0], ',', rp[1])
# Out:
# Roots by quadratic method: 1.0 , -1.0
# Roots by Po Shen Loh method: 1.0 , -1.0

# %% [markdown]
# - $x^{2} + 1 = 0$

# %%
rq = quadratic(1,0,1)
print('Roots by quadratic method:', rq[0], ',', rq[1])
rp = poshenloh(0,1)
print('Roots by Po Shen Loh method:', rp[0], ',', rp[1])
# Out:
# Roots by quadratic method: 1j , -1j
# Roots by Po Shen Loh method: 1j , -1j

# %% [markdown]
# **3.** To plot the newton fractals for the corresponding complex quadratic polynomials

# %% [markdown]
# - $z^{2}$

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):

    # Fractals using newton-raphson

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    # Step size for numerical derivative
    h = 1e-7
    # Max error allowed
    eps = 1e-3 

    # Bounding roots
    r1 = 0

    # Color multiplication factor
    # Note: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # Complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    # Newton iteration
                    znext = z - f(z) / dz 

                    # Stop when close enough to any root
                    if abs(znext - z) < eps: 
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # Color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    
    # Display a newton-raphson fractal

    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x) = $z^{2}$')
    plt.xlabel("Real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("Imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
display1(zoom=0.01)
# Out:
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )

# %% [markdown]
# - $(z-1)^2$

# %%
# (z-1)^2 = z^2 - 2z + 1

def f(z):
    return z ** 2 - 2 * z + 1

def df(z):
    return 2 * z - 2

def newton_set2(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):

    # Fractals using newton-raphson

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    # Step size for numerical derivative
    h = 1e-7
    # Max error allowed 
    eps = 1 

    # Bounding roots
    r1 = 1

    # Color multiplication factor
    # Note: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # Complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    # Newton iteration
                    znext = z - f(z) / dz 

                    # Stop when close enough to any root
                    if abs(znext - z) < eps: 
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # Color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    
    # Display a newton-raphson fractal

    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x) = $z^{2}-2z+1$')
    plt.xlabel("Real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("Imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
display2(zoom=0.01)
# Out:
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )

# %% [markdown]
# - $z^{2} – 1$

# %%
def f(z):
    return z ** 2 - 1

def df(z):
    return 2 * z

def newton_set3(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    
    # Fractals using newton-raphson

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    # Step size for numerical derivative
    h = 1e-7 
    # Max error allowed
    eps = 1e-3 

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # Note: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # Complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    # Newton iteration
                    znext = z - f(z) / dz 

                    # Stop when close enough to any root
                    if abs(znext - z) < eps: 
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # Color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # Color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    
    # Display a newton-raphson fractal

    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x) = $z^{2}-1$')
    plt.xlabel("Real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("Imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
display3(zoom=1)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )

# %% [markdown]
# - $z^2 + 1$

# %%
def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

def newton_set4(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    
    # Fractals using newton-raphson

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    # Step size for numerical derivative
    h = 1e-7 
    # Max error allowed
    eps = 1e-3 

    # Bounding roots
    r1 = complex(0,1)
    r2 = complex(0,-1)

    # Color multiplication factor
    # Note: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # Complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    # Newton iteration
                    znext = z - f(z) / dz 

                    # Stop when close enough to any root
                    if abs(znext - z) < eps: 
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # Color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # Color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    
    # Display a newton-raphson fractal

    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set4(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x) = $z^{2}+1$')
    plt.xlabel("Real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("Imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
display4(zoom=1)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )

# %% [markdown]
# **4.** Plot the Newton iterates for points on the positive and negative axes for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# ### $x^2$

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form $z = 10.0 + 0.0j$

# %%
z = 10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 + 0.0j$

# %%
z = -10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 + 10.0j$

# %%
z = 0.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 - 10.0j$

# %%
z = 0.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# In every case, takes less than 10 iterations to converge to the single root, which is 0. This is due to the real part converge to 0 and the imaginary part too.

# %% [markdown]
# - $(x-1)^{2}$

# %%
# (x-1)^2 = x^2 -2x +1

def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z - 2

# %% [markdown]
# Newton iterates form $z = 10.0 + 0.0j$

# %%
z = 10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 + 0.0j$

# %%
z = -10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 + 10.0j$

# %%
z = 0.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 - 10.0j$

# %%
z = 0.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# In every case, takes less than 10 iterations to converge to the single root, which is 0. This is due to the real part converge to 1 and the imaginary part converge to 0.

# %% [markdown]
# - $x^{2} - 1$

# %%
def f(z):
    return z**2 - 1

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form $z = 10.0 + 0.0j$

# %%
z = 10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 + 0.0j$

# %%
z = -10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 + 10.0j$

# %%
z = 0.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 - 10.0j$

# %%
z = 0.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# For $z = 10.0 + 0.0j$, the real part converge to 1 and the imaginary part converge to 0.
#
# For $z = -10.0 + 0.0j$, the real part converge to -1 and the imaginary part converge to 0.
#
# For $z = 0.0 + 10.0j$, the real part converge to 0 but the imaginary part diverge.
#
# For $z = 0.0 - 10.0j$, the real part converge to 0 but the imaginary part diverge.
#
# This is due to the imaginary part could be any number 'cause
# convergence of the funtion depends of the real part.

# %% [markdown]
# ### $x^2 + 1$

# %%
def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form $z = 10.0 + 0.0j$

# %%
z = 10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 + 0.0j$

# %%
z = -10.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 + 10.0j$

# %%
z = 0.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 - 10.0j$

# %%
z = 0.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# For  $z = 10.0 + 0.0j$, the imaginary part converge to 0 and the real part diverge.
#
# For  $z = −10.0 + 0.0j$, the imaginary part converge to 0 and the real part diverge.
#
# For  $z = 0.0 + 10.0j$, the imaginary part converge to 1 and the real part converge to 0.
#
# For  $z = 0.0 − 10.0j$, the imaginary part converge to -1 and the real part converge to 0.
#
# This is due to the real part could be any number 'cause convergence of the funtion depends of the imaginary part.

# %% [markdown]
# **5.** Plot he Newton iterates for points on the diagonals in the four quadrants and 0.0 + 0.0j for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# - $z^2$

# %%
def f(z):
    return z ** 2

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form $z = 10.0 + 10.0j$

# %%
z = 10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 + 10.0j$

# %%
z = -10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 10.0 - 10.0j$

# %%
z = 10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = -10.0 - 10.0j$

# %%
z = -10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form $z = 0.0 + 0.0j$

# %%
z = 0.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-46-88bdf3a194a9> in <module>()
#       5   dz = df(z)
#       6   # Newton iteration
# ----> 7   z = z - f(z) / dz
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# In this case, the only root is 0 so the only value of convergence is 0 in any case.
#
# For $z = 0.0 + 0.0j$ there is an exception 'cause there is a division by 0 at the momento of value the $df(x)$ function. ($df(0) = 2(0) = 0$)

# %% [markdown]
# - $(x-1)^{2}$

# %%
# (x-1)^2 = x^2 -2x + 1

def f(z):
    return z**2 - 2*z + 1

def df(z):
    return 2 * z -2

# %% [markdown]
# Newton iterates form  $z = 10.0 + 10.0j$

# %%
z = 10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))
  
plt.title('Newton iterates form $z = 10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 + 10.0j$

# %%
z = -10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))
  
plt.title('Newton iterates form $z = -10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 10.0 - 10.0j$

# %%
z = 10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))
  
plt.title('Newton iterates form $z = 10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 - 10.0j$

# %%
z = -10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))
  
plt.title('Newton iterates form $z = -10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 0.0 + 0.0j$

# %%
z = 0.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))
  
plt.title('Newton iterates form $z = 0.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# In this case, the only root is 1 so the only value of convergence is 0 in any case. This means the real part converge always to 1 and the imaginary part converge always to 0.
#
# For $z = 0.0 + 0.0j$ happends the same with the real and imaginary part, this due to there isn´t an exception 'cause $df(0) = 2(0) - 2 = -2 \not = 0$.

# %% [markdown]
# ### $x^2 - 1$

# %%
def f(z):
    return z ** 2 - 1

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form  $z = 10.0 + 10.0j$

# %%
z = 10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 + 10.0j$

# %%
z = -10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 10.0 - 10.0j$

# %%
z = 10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 - 10.0j$

# %%
z = -10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 0.0 + 0.0j$

# %%
z = 0.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-58-88bdf3a194a9> in <module>()
#       5   dz = df(z)
#       6   # Newton iteration
# ----> 7   z = z - f(z) / dz
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# As we say in the item 4, the convergece of the funciton only depends of the real part, it means:
#
# For $z = 10.0 + 10.0j$ and for $z = 10.0 - 10.0j$ the real part converge to 1 and the imaginary part converge to 0.
#
# For $z = -10.0 + 10.0j$ and for $z = -10.0 - 10.0j$ the real part converge to -1 and the imaginary part converge to 0.
#
# For $z = 0.0 + 0.0j$ there is an exception 'cause there is a division by 0 at the momento of value the $df(x)$ function. ($df(0) = 2(0) = 0$)

# %% [markdown]
# ### $x^2 + 1$

# %%
def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

# %% [markdown]
# Newton iterates form  $z = 10.0 + 10.0j$

# %%
z = 10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 + 10.0j$

# %%
z = -10.0 + 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 10.0 - 10.0j$

# %%
z = 10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = -10.0 - 10.0j$

# %%
z = -10.0 - 10.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = -10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Newton iterates form  $z = 0.0 + 0.0j$

# %%
z = 0.0 + 0.0j
r = []
i = []
for k in range(50):
  dz = df(z)
  # Newton iteration
  z = z - f(z) / dz 
  r.append(np.real(z))
  i.append(np.imag(z))

plt.title('Newton iterates form $z = 0.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-64-88bdf3a194a9> in <module>()
#       5   dz = df(z)
#       6   # Newton iteration
# ----> 7   z = z - f(z) / dz
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# As we say in the item 4, the convergece of the funciton only depends of the imaginary part, it means:
#
# For $z = 10.0 + 10.0j$ and for $z = -10.0 + 10.0j$ the imaginary part converge to 1 and the real part converge to 0.
#
# For $z = 10.0 - 10.0j$ and for $z = -10.0 - 10.0j$ the imaginary part converge to -1 and the real part converge to 0.
#
# For $z = 0.0 + 0.0j$ there is an exception 'cause there is a division by 0 at the momento of value the $df(x)$ function. ($df(0) = 2(0) = 0$)
